# %% [markdown]
# ## **Practical 2** Introduction to Pandas, Matplotlib and Sklearn

# %% [markdown]
# ### **I. Extracting tables from .pdf file and storing each in separate .csv file using TABULA**

# %%
# !java -version
# Out:
# openjdk version "11.0.8" 2020-07-14
# OpenJDK Runtime Environment (build 11.0.8+10-post-Ubuntu-0ubuntu118.04.1)
# OpenJDK 64-Bit Server VM (build 11.0.8+10-post-Ubuntu-0ubuntu118.04.1, mixed mode, sharing)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-80c52220-924e-4fba-b4ed-fbd727f55bc4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-80c52220-924e-4fba-b4ed-fbd727f55bc4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving OScoursepolicy.pdf to OScoursepolicy.pdf

# %%
# To be more precisely, it's better to use `{sys.executable} -m pip install tabula-py`
# !pip install -q tabula-py

# %%
import tabula

tabula.environment_info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-2a05a9e57b5e> in <module>()
#       1 import tabula
#       2
# ----> 3 tabula.environment_info()
#
# AttributeError: module 'tabula' has no attribute 'environment_info'

# %%
import tabula
pdf_path = "https://github.com/chezou/tabula-py/raw/master/tests/resources/data.pdf"

dfs = tabula.read_pdf(pdf_path, stream=True)
# read_pdf returns list of DataFrames
print(len(dfs))
dfs[0]
# Out:
# 'pages' argument isn't specified.Will extract only from page 1 by default.
# Got stderr: Oct 07, 2020 4:22:51 PM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider loadDiskCache
# WARNING: New fonts found, font cache will be re-built
# Oct 07, 2020 4:22:51 PM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider <init>
# WARNING: Building on-disk font cache, this may take a while
# Oct 07, 2020 4:22:51 PM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider <init>
# WARNING: Finished building on-disk font cache, found 17 fonts
# Oct 07, 2020 4:22:51 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font Symbol
# Oct 07, 2020 4:22:51 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font ZapfDingbats
# 1
#              Unnamed: 0   mpg  cyl   disp   hp  ...   qsec  vs  am  gear  carb
# 0             Mazda RX4  21.0    6  160.0  110  ...  16.46   0   1     4     4
# ...
